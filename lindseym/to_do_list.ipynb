# %% [markdown]
# Things to be done:
#
# logistics:
# - put dates/times are in proper datetime objects
# - datatypes in general
# - create new source category that is more general (urine, wound, blood, resp, body fluid, csf)
#
# content:
# - exclude surveillance isolates
# - only final verified results should be included (I think all of ours should be)
# - only include species with testing data for >30 isolates
# - deduplicate - only include the first isolate of a species per patient per year regardles of source or susceptibility profile
# - calculate the %susceptible (exclude I and SDD)
# - could make separate antibiograms by:
#     - source
#     - patient type (inpatient vs outpatient)
# - antibiograms are made per year - depending on the amount of refined data we have, indicate time period and maybe just do one year
# - use green/yellow/red in a heatmap
